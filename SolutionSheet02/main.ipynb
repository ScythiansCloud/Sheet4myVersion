# %%
# from misc import timeit
import numpy as np
from Simulation import SimluationSheet4
import pandas as pd
import matplotlib.pyplot as plt
import settings

# %%
SimluationSheet4(True, 'testtrajectory1', 30)
# Out:
# 100%|██████████| 50000/50000 [00:47<00:00, 1049.31it/s]
# 100%|██████████| 9/9 [00:00<00:00, 907.33it/s]

# %%
arr = pd.read_csv('testtrajectory130Energyeq',header = None , delimiter=' ').values

# %%
arr.shape
# Out:
# (1668, 6)

# %%
plt.plot(arr[:,0], arr[:,2])

# %%
plt.plot(arr[:,0], arr[:,3])
plt.plot(arr[:,0], arr[:,4])
plt.plot(arr[:,0], arr[:,5])
plt.yscale('log')
plt.xlim([0,5000])
# Out:
# (0.0, 5000.0)
